# %% [markdown]
# # BeautifulSoup가 필요한 이유
# 텍스트형태의 데이터에서 원하는 html 태그를 추출할 수 있을까요?
#
# 이를 쉽게 할 수 있게 도와주는 녀석이 바로 "뷰티풀수프"입니다.
#
# 즉, html을 수프객체로 만들어서 추출하기 쉽게 만들어줘요.

# %% [markdown]
# ##웹 문서 전체 가져오기기

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.naver.com/'

response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    print(soup)

else :
    print(response.status_code)
# Out:
#  <!DOCTYPE html>
#  <html class="fzoom" lang="ko"> <head> <meta charset="utf-8"/> <meta content="origin" name="Referrer"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <title>NAVER</title> <meta content="NAVER" name="apple-mobile-web-app-title"> <meta content="index,nofollow" name="robots"> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content="https://www.naver.com/" name="twitter:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"> <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/> <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed"> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_231130.css" rel="stylesheet"/> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js"></script> <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"개꿈","url":"https://comic.naver.com/webtoon/list?titleId=818791","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F818791%2Fthumbnail%2Fthumbnail_IMAG21_a613db8b-8319-4bfe-8971-1df89f4df979.jpg%22&type=nf216_280&service=navermain"},"desc":"신송림","webtoonIcon":{"newest":true,"adult":true,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c64"},{"@type":"MATERIAL-PC-FEED","title":"호랑이형님","url":"https://comic.naver.com/webtoon/list?titleId=650305","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F650305%2Fthumbnail%2Fthumbnail_IMAG21_3631086797392995425.jpg%22&type=nf216_280&service=navermain"},"desc":"이상규","webtoonIcon":{"newest":false,"adult":false,"up":false,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c65"},{"@type":"MATERIAL-PC-FEED","title":"초인의 시대","url":"https://comic.naver.com/webtoon/list?titleId=730694","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F730694%2Fthumbnail%2Fthumbnail_IMAG21_e6fc219d-e5ea-4d93-b7d6-45b595c2a3cb.jpeg%22&type=nf216_280&service=navermain"},"desc":"섭이","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c66"},{"@type":"MATERIAL-PC-FEED","title":"마도전생기","url":"https://comic.naver.com/webtoon/list?titleId=807777","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F807777%2Fthumbnail%2Fthumbnail_IMAG21_e47489ea-bf97-4726-a8e7-6403092a303a.jpg%22&type=nf216_280&service=navermain"},"desc":"포스스튜디오 / codezero","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c67"},{"@type":"MATERIAL-PC-FEED","title":"욕망일기Deep","url":"https://comic.naver.com/webtoon/list?titleId=818448","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F818448%2Fthumbnail%2Fthumbnail_IMAG21_8f02d84a-1c44-412e-8a34-4c9ec09c68ac.jpg%22&type=nf216_280&service=navermain"},"desc":"김꿀빨 / 누리마루","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c68"},{"@type":"MATERIAL-PC-FEED","title":"망나니 소교주로 환생했다","url":"https://comic.naver.com/webtoon/list?titleId=773796","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F773796%2Fthumbnail%2Fthumbnail_IMAG21_8ecfa6b5-8018-4640-8a4b-97e14d06a4c5.jpg%22&type=nf216_280&service=navermain"},"desc":"재무 / 전마두 / 대은호","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c69"},{"@type":"MATERIAL-PC-FEED","title":"작전명 순정","url":"https://comic.naver.com/webtoon/list?titleId=793275","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F793275%2Fthumbnail%2Fthumbnail_IMAG21_30c77a8d-ada1-40f8-b87a-d02bb05e7e13.jpg%22&type=nf216_280&service=navermain"},"desc":"꼬까리 / 들덤","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c6a"},{"@type":"MATERIAL-PC-FEED","title":"아홉수 우리들","url":"https://comic.naver.com/webtoon/list?titleId=724815","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2
classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",(()=>{var e;(e=document.getElementById("header"))&&e.classList.contains("ani_fixed")?t&&t.classList.remove("type_special_logo_full"):t&&t.classList.add("type_special_logo_full")}))}var c=o&&o.content&&o.content.input&&o.content.input.placeholder;if(c){var l=document.getElementById("query");l&&c&&l.setAttribute("title",c),l&&c&&l.setAttribute("placeholder",c)}}else t()}()</script> </body> </html>

# %% [markdown]
# 네이버 웹 사이트 입니다 응답 코드가 200 일때, html 을 받아와 soup 객체로 변환 합니다.

# %% [markdown]
# ##타이틀 가져오기기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.naver.com")
bsObject = BeautifulSoup(html, "html.parser")

print(bsObject.head.title)
# Out:
# <title>NAVER</title>

# %% [markdown]
# 특정 제목만을 뽑아 올수 있습니다 html의 parser부분만 따서 제목만을 가져올수 있습니다다

# %% [markdown]
# ##모든 메타 데이터 가져오기기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.naver.com")
bsObject = BeautifulSoup(html, "html.parser")


for meta in bsObject.head.find_all('meta'):
    print(meta.get('content'))
# Out:
# None
# origin
# IE=edge
# width=1190
# NAVER
# index,nofollow
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요
# 네이버
# https://www.naver.com/
# https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요
# summary
#
# https://www.naver.com/
# https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %% [markdown]
# ##원하는 태그 내용 가져오기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.naver.com/")#url
bsObject = BeautifulSoup(html, "html.parser")


print (bsObject.head.find("meta", {"name":"description"}).get('content'))#요부분 내용 가져오기기
# Out:
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %% [markdown]
# ##모든 링크의 텍스트와 주소 가져오기기

# %%
html = urlopen("https://www.naver.com")
bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('a'):
    print(link.text.strip(), link.get('href'))
# Out:
# 상단영역 바로가기 #topAsideButton
# 서비스 메뉴 바로가기 #shortcutArea
# 새소식 블록 바로가기 #newsstand
# 쇼핑 블록 바로가기 #shopping
# 관심사 블록 바로가기 #feed
# MY 영역 바로가기 #account
# 위젯 보드 바로가기 #widgetboard
# 보기 설정 바로가기 #viewSetting
# 전체삭제 #
# 도움말 https://help.naver.com/alias/search/word/word_35.naver
# 도움말 https://help.naver.com/alias/search/word/word_35.naver
# 자동저장 끄기 #
# 도움말 https://help.naver.com/alias/search/word/word_35.naver
# 닫기 #
# 이 정보가 표시된 이유 #
# 레이어 닫기 #
# 자세히보기 #
# 관심사를 반영한 컨텍스트 자동완성도움말 https://help.naver.com/alias/search/word/word_16.naver
# 컨텍스트 자동완성 #
# 자세히 보기 https://help.naver.com/alias/search/word/word_16.naver
# 자세히 보기 https://help.naver.com/support/alias/search/word/word_16.naver
# 네이버로그인 https://nid.naver.com/nidlogin.login
# 컨텍스트 자동완성 레이어 닫기 #
# 자동완성 끄기 #
# 도움말 https://help.naver.com/alias/search/word/word_17.naver
# 신고 https://help.naver.com/alias/search/word/word_18.naver
# 닫기 #

# %% [markdown]
# 본격적으로 응용을 해보겠습니다 위에서는 기초적인 부분을 탐구하였다면 이제 아래 부분에서 부터는 본격적인 응용을 시작해 보겠습니다.

# %% [markdown]
# #교보문고 베스트셀러 긁어오기기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup



# 교보문고의 베스트셀러 웹페이지를 가져옵니다.
html = urlopen('http://www.kyobobook.co.kr/bestSellerNew/bestseller.laf?orderClick=d79&NaPm=ct%3Dkv93nlbs%7Cci%3Dcheckout%7Ctr%3Dds%7Ctrx%3D%7Chk%3D2b68031da2b07a6cde9e9639db1d4f669a71454b')
bsObject = BeautifulSoup(html, "html.parser")



# 책의 상세 웹페이지 주소를 추출하여 리스트에 저장합니다.
book_page_urls = []
for cover in bsObject.find_all('div', {'class':'detail'}):
    link = cover.select('a')[0].get('href')
    book_page_urls.append(link)


# 메타 정보로부터 필요한 정보를 추출합니다.메타 정보에 없는 저자 정보만 따로 가져왔습니다.
for index, book_page_url in enumerate(book_page_urls):
    html = urlopen(book_page_url)
    bsObject = BeautifulSoup(html, "html.parser")
    title = bsObject.find('meta', {'property':'og:title'}).get('content')
    author = bsObject.select('span.name a')[0].text
#  image = bsObject.find('meta', {'property':'og:image'}).get('content')
#    url = bsObject.find('meta', {'property':'og:url'}).get('content')
    Price = bsObject.find('meta', {'property': 'og:price'}).get('content')

    print(index+1, title, author, Price)

# %% [markdown]
# #기상청청 긁어오기기

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('https://www.billboard.com/charts/hot-100/')

html = req.text

soup = BeautifulSoup(html, 'html.parser')

rank = soup.select(
   'li > button > span.chart-element__rank.flex--column.flex--xy-center.flex--no-shrink > span.chart-element__rank__number'
)

# %%
import requests
from bs4 import BeautifulSoup
import pandas
import matplotlib as mpl
import matplotlib.pyplot as plt


source = requests.get('https://www.weather.go.kr/weather/observation/currentweather.jsp')
soup = BeautifulSoup(source.content,"html.parser")

table = soup.find('table',{'class':'table_develop3'})
data = []

print("#"*30)
print("\nHello! Here's today's weather!\n")
print("#"*30)

for tr in table.find_all('tr'):
    tds = list(tr.find_all('td'))
    for td in tds:
        if td.find('a'):
            point = td.find('a').text
            temp = tds[5].text
            humidity = tds[9].text
            print("{0:<7} {1:<7} {2:<7}".format(point,temp,humidity))
            data.append([point,temp,humidity])

print("#"*30)
print("\nIt ends here. thanks!\n")
print("#"*30)

print(data)

with open('weather.csv','w') as f:
    f.write('지역, 온도, 습도\n')
    for i in data:
        f.write('{0},{1},{2}\n'.format(i[0],i[1],i[2]))




plt.show()
# Out:
# ##############################
#
# Hello! Here's today's weather!
#
# ##############################
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-e861fcf03b85> in <cell line: 18>()
#      16 print("#"*30)
#      17
# ---> 18 for tr in table.find_all('tr'):
#      19     tds = list(tr.find_all('td'))
#      20     for td in tds:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# # 후기
# bs4의 기본적인 부분을 탐구해 보았고 생각보다 어렵지 않게 응용이 가능했다. 또한 실질적으로 필요한 자료들을 쉽고 간단하게 임포트 가능했고 엑셀 파일로 변환하기도 간단하였다. 빅 데이터를 응용할때 필요한 파일들을 궂이 케글에서 찾을 필요 없이 내가 직접 자료를 구할수 있다는 점에서 뜻깊었다
